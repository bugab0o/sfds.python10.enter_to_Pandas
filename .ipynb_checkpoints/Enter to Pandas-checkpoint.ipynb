# %% [markdown]
# PYTHON-10.Введение в Pandas

# %% [markdown]
# Рассмотрим несколько способов создания Series на примере со списком названий стран.

# %%
import pandas as pd

# %%
countries = pd.Series(
    data = ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ'],
    name = 'countries'
)
display(countries)
# Out:
# UK       Англия
# CA       Канада
# US          США
# RU       Россия
# UA      Украина
# BY     Беларусь
# KZ    Казахстан
# Name: countries, dtype: object

# %% [markdown]
# ДОСТУП К ДАННЫМ В SERIES
# Доступ к элементам осуществляется с использованием loc или iloc.

# %%
print(countries.loc['US'])
# Out:
# США

# %%
print(countries.loc[['US', 'RU', 'UK']])
# Out:
# US       США
# RU    Россия
# UK    Англия
# Name: countries, dtype: object

# %%
print(countries.iloc[6])
# Out:
# Казахстан

# %%
print(countries.iloc[1:4])
# Out:
# CA    Канада
# US       США
# RU    Россия
# Name: countries, dtype: object

# %%
countries[['UK', 'US', 'UA']]
countries[[0, 2, 4]]
# Out:
# UK     Англия
# US        США
# UA    Украина
# Name: countries, dtype: object

# %% [markdown]
# DATAFRAME КАК СТРУКТУРА ДАННЫХ

# %% [markdown]
# Самый простой способ создания DataFrame — из словаря,
# ключами которого являются имена столбцов будущей таблицы,
# а значениями — списки, в которых хранится содержимое этих столбцов:

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})
countries_df.index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %% [markdown]
# Также DataFrame можно создать из вложенного списка,
# внутренние списки которого будут являться строками новой таблицы:

# %%
countries_df = pd.DataFrame(
    data = [
        ['Англия', 56.29, 133396],
        ['Канада', 38.05, 9984670],
        ['США', 322.28, 9826630],
        ['Россия', 146.24, 17125191],
        ['Украина', 45.5, 603628],
        ['Беларусь', 9.5, 207600],
        ['Казахстан', 17.04, 2724902]
    ],
    columns= ['country', 'population', 'square'],
    index = ['UK', 'CA', 'US', 'RU', 'UA', 'BY', 'KZ']
)

display(countries_df)
# Out:
#       country  population    square
# UK     Англия       56.29    133396
# CA     Канада       38.05   9984670
# US        США      322.28   9826630
# RU     Россия      146.24  17125191
# UA    Украина       45.50    603628
# BY   Беларусь        9.50    207600
# KZ  Казахстан       17.04   2724902

# %% [markdown]
# Рассмотрим разницу в результатах работы методов в зависимости от параметра axis на примере использования метода DataFrame mean() — вычисление среднего по таблице.

# %% [markdown]
# Считаем среднее по строкам (axis = 0) в каждом столбце:
# display(countries_df.mean(axis=0))
#
#
# Считаем среднее по столбцам (axis = 1) в каждой строке:
# countries_df.mean(axis=1)
#
# Можно обратиться к DataFrame по имени столбца через точку:
#
# countries_df.population
#
# или
#
# Другой вариант — обратиться к DataFrame по индексу и указать имя столбца:
#
# countries_df['population']

# %%
import pandas as pd

countries_data = pd.read_csv('C:/Users/olegi/Desktop/projects/SFDS.HW/sfds.python10.enter to Pandas/data/countries.csv', sep=';')
display(countries_data)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
# ----> 3 countries_data = pd.read_csv('C:/Users/olegi/Desktop/projects/SFDS.HW/sfds.python10.enter to Pandas/data/countries.csv', sep=';')
#       4 display(countries_data)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:814, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:875, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:850, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\parsers.pyx:2029, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0  \
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize
# 0          S      Biggin   3/12/2016       2.5  ...       1.0  1.0     202.0  \
# 1          S      Biggin   4/02/2016       2.5  ...       1.0  0.0     156.0
# 2         SP      Biggin   4/03/2017       2.5  ...       2.0  0.0     134.0
# 3         PI      Biggin   4/03/2017       2.5  ...       2.0  1.0      94.0
# 4         VB      Nelson   4/06/2016       2.5  ...       1.0  2.0     120.0
# ...      ...         ...         ...       ...  ...       ...  ...       ...
# 18391     SP        Greg  26/08/2017       6.8  ...       2.0  1.0       NaN
# 18392     PI     Sweeney  26/08/2017       6.8  ...       1.0  5.0     866.0
# 18393      S  Buckingham  26/08/2017      12.7  ...       3.0  2.0       NaN
# 18394     SP     Village  26/08/2017       6.3  ...       1.0  1.0     362.0
# 18395     VB     Village  26/08/2017       6.3  ...       2.0  2.0       NaN
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude
# 0               NaN        NaN        Yarra  -37.79960  144.99840  \
# 1              79.0     1900.0        Yarra  -37.80790  144.99340
# 2             150.0     1900.0        Yarra  -37.80930  144.99440
# 3               NaN        NaN        Yarra  -37.79690  144.99690
# 4             142.0     2014.0        Yarra  -37.80720  144.99410
# ...             ...        ...          ...        ...        ...
# 18391          89.0     2010.0          NaN  -37.86393  144.90484
# 18392         157.0     1920.0          NaN  -37.85908  144.89299
# 18393           NaN        NaN          NaN  -37.72006  145.10547
# 18394         112.0     1920.0          NaN  -37.81188  144.88449
# 18395         139.0     1950.0          NaN  -37.81829  144.87404
#
#                   Regionname  Propertycount
# 0      Northern Metropolitan         4019.0
# 1      Northern Metropolitan         4019.0
# 2      Northern Metropolitan         4019.0
# 3      Northern Metropolitan         4019.0
# 4      Northern Metropolitan         4019.0
# ...                      ...            ...
# 18391   Western Metropolitan         6380.0
# 18392   Western Metropolitan         6380.0
# 18393  Northern Metropolitan         1369.0
# 18394   Western Metropolitan         6543.0
# 18395   Western Metropolitan         6543.0
#
# [18396 rows x 22 columns]

# %%
import pandas as pd
melb_data = pd.read_csv('C:/Users/olegi/Desktop/projects/SFDS.HW/sfds.python10.enter to Pandas/data/melb_data.csv', sep=',')

# display(melb_data.head())

# melb_data.tail(7)

melb_data.shape

melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()

# melb_data.describe()
# melb_data.describe().loc[:, ['Distance', 'BuildingArea' , 'Price']]

# melb_data.describe(include=['object'])

# melb_data['Regionname'].value_counts()
melb_data['Type'].value_counts(normalize=True)

# %%
print(melb_data['Price'].mean())
print(melb_data['Car'].max())

rate = 0.12
income = melb_data['Price'].sum() * rate
print('Total income of real estate agencies:', round(income, 2))

landsize_median = melb_data['Landsize'].median()
landsize_mean = melb_data['Landsize'].mean()
print(abs(landsize_median - landsize_mean)/landsize_mean)
# Out:
# 1075684.079455081
# 10
# Total income of real estate agencies: 1752934775.88
# 0.21205713983546193

# %%
import numpy as np
import pandas as pd

solar_data = pd.read_csv('./solarpower.csv')
solar_data.replace(-1, np.nan, inplace=True)

solar_data['cum_power'].interpolate(method='linear', inplace=True)

# display(solar_data.head(5))
# display(solar_data['cum_power'].mean())

# solar_data.info()
solar_data['day_power'] = solar_data['cum_power'] - solar_data['cum_power'].shift(1)
solar_data['date'] = pd.to_datetime(solar_data['date'])
solar_data['month_year'] = solar_data['date'].dt.to_period('M')
monthly_average = solar_data.groupby('month_year')['day_power'].mean()
average_march_2017 = int(monthly_average['2017-03'].round())

display(average_march_2017)

monthly_average['day_power'].plot(
    kind='line',
    lw=3, 
    title='Monthly average',
    xlabel='Year - month',
    ylabel='Average',
    figsize=(10, 5)
);
# Out:
# 11
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\period.py:409, in PeriodIndex.get_loc(self, key)
#     408 try:
# --> 409     parsed, reso = self._parse_with_reso(key)
#     410 except ValueError as err:
#     411     # A string with invalid format
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\datetimelike.py:267, in DatetimeIndexOpsMixin._parse_with_reso(self, label)
#     265     label = str(label)
# --> 267 parsed, reso_str = parsing.parse_datetime_string_with_reso(label, freqstr)
#     268 reso = Resolution.from_attrname(reso_str)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\tslibs\parsing.pyx:435, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\tslibs\parsing.pyx:658, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: Unknown datetime string format, unable to parse: day_power
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[72], line 21
#      17 average_march_2017 = int(monthly_average['2017-03'].round())
#      19 display(average_march_2017)
# ---> 21 monthly_average['day_power'].plot(
#      22     kind='line',
#      23     lw=3,
#      24     title='Monthly average',
#      25     xlabel='Year - month',
#      26     ylabel='Average',
#      27     figsize=(10, 5)
#      28 );
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\period.py:412, in PeriodIndex.get_loc(self, key)
#     409     parsed, reso = self._parse_with_reso(key)
#     410 except ValueError as err:
#     411     # A string with invalid format
# --> 412     raise KeyError(f"Cannot interpret '{key}' as period") from err
#     414 if self._can_partial_date_slice(reso):
#     415     try:
#
# KeyError: "Cannot interpret 'day_power' as period"
